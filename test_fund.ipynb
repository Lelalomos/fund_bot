# %%
import pythainav as nav

# %%
f = nav.sources.Finnomena()

# %%
f.list()
# Out:
# {'TMB50': {'id': 'F000000QSX',
#   'short_code': 'TMB50',
#   'name_th': 'กองทุนเปิดทหารไทย SET50',
#   'aimc_category_id': 'LC00002660',
#   'is_nter_pick': False},
#  'ABG': {'id': 'F000000QU8',
#   'short_code': 'ABG',
#   'name_th': 'กองทุนเปิด อเบอร์ดีน โกรท',
#   'aimc_category_id': 'LC00002470',
#   'is_nter_pick': False},
#  'ABLTF': {'id': 'F000000QU9',
#   'short_code': 'ABLTF',
#   'name_th': 'กองทุนเปิด อเบอร์ดีน หุ้นระยะยาว',
#   'aimc_category_id': 'LC00002470',
#   'is_nter_pick': False},
#  'ABSL': {'id': 'F000000QWJ',
#   'short_code': 'ABSL',
#   'name_th': 'กองทุนเปิด อเบอร์ดีน สยาม ลีดเดอร์ส',
#   'aimc_category_id': 'LC00002470',
#   'is_nter_pick': False},
#  'ABV': {'id': 'F000000QWL',
#   'short_code': 'ABV',
#   'name_th': 'กองทุนเปิด อเบอร์ดีน แวลู',
#   'aimc_category_id': 'LC00002490',
#   'is_nter_pick': False},
#  'ABSM': {'id': 'F000000QWM',
#   'short_code': 'ABSM',
#   'name_th': 'กองทุนเปิด อเบอร์ดีน สมอล-มิดแค็พ - ชนิดสะสมมูลค่า',
# ...

# %%
key_target = list()
for k,v in f.list().items():
    if 'จ่ายเงินปันผล' in v['name_th']:
        key_target.append(k)
key_target
# Out:
# ['K-GA-A(D)',
#  'KTFIXPLUS-D',
#  'SCBPMO',
#  'ASP-LTF-T',
#  '1AMSET50-RA',
#  'PRINCIPAL GCF-D',
#  'K-GOLD-A(D)',
#  'K-CHINA-A(D)',
#  'UOBSG-N',
#  'UOBSG-D',
#  'UOBSCI-N',
#  'UOBSCI-D',
#  'SCBSE',
#  'SCBENERGY',
#  'SCBBANKING',
#  'ONE-EC14-RD',
#  'KKP ACT EQ-D',
#  'KT-PROPERTY-D',
#  'PRINCIPAL iPROP-D',
#  'PRINCIPAL iDAILY-D',
#  'PRINCIPAL iDIV-D',
#  'K-USA-A(D)',
#  'LHDEBT-D',
#  'LHEQD-D',
#  'SCBGEQ',
#  'K-USXNDQ-A(D)',
#  'K-EUROPE-A(D)',
#  'SCBNK225D',
#  'KT-OPP-D',
#  'K-GB-A(D)',
#  'KWI HCARE-D',
#  'K-GPROP-A(D)',
#  'KWI INDIA-D',
#  'TISESG-D',
#  'ONE-UGG-RA',
#  'KT-INDIA-D',
#  'K-GINFRA-A(D)',
#  'KFGPROP-D',
#  'LHIP-D',
#  'LHSMART-D',
#  'KT-JAPAN-D',
#  'KT-PIF-D',
#  'KFGBRAND-D',
#  'LHJAPE-D',
#  'LHMSFL-D',
#  'LHSMARTLTF-D',
#  'LHPROPINFRA-D',
#  'LHPROPIA-D',
#  'LHACTLTF-D',
#  'PRINCIPAL TDIF-D',
#  'ONE-POWER',
#  'LHSTRATEGY-D',
#  'KT-CLMVT-D',
#  'LHSELECT-D',
#  'LHGINCOME-D',
#  'LHGLIFEE-D',
#  'LHTOPPICK-D',
# ...

# %%
len(list(f.list().keys()))
# Out:
# 2710

# %%
df = nav.get_all("K-GOLD-A(D)", asDataFrame=True)

# %%
df.head()
# Out:
#      value    updated tags         fund
# 0  11.2383 2022-02-17   {}  K-GOLD-A(D)
# 1  11.2923 2022-02-18   {}  K-GOLD-A(D)
# 2  11.3128 2022-02-22   {}  K-GOLD-A(D)
# 3  11.2775 2022-02-23   {}  K-GOLD-A(D)
# 4  11.5958 2022-02-24   {}  K-GOLD-A(D)
